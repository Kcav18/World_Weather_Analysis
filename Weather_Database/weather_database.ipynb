# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000,high=90.000, size = 2000)
lngs = np.random.uniform(low=-180.000,high=180.000,size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Use the `citipy` module to get the nearest city for each latitude and longitude combination.
from citipy import citipy

# Create an empty list for holding the cities
cities=[]

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
         cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 749

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ff5be8cc36b0f0ebaf6d8361daef36c

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        #time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
 
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_description = city_weather["weather"][0]["description"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]     
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')    
      
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | hithadhoo
# Processing Record 5 of Set 1 | bredasdorp
# Processing Record 6 of Set 1 | tuktoyaktuk
# Processing Record 7 of Set 1 | vangaindrano
# Processing Record 8 of Set 1 | kavaratti
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | hasaki
# Processing Record 11 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 1 | atuona
# Processing Record 13 of Set 1 | shchelyayur
# City not found. Skipping...
# Processing Record 14 of Set 1 | kapaa
# Processing Record 15 of Set 1 | mahebourg
# Processing Record 16 of Set 1 | hofn
# Processing Record 17 of Set 1 | morro da fumaca
# Processing Record 18 of Set 1 | sarkand
# Processing Record 19 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 1 | tammisaari
# Processing Record 21 of Set 1 | ribeira grande
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | yellowknife
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | sur
# Processing Record 26 of Set 1 | sao filipe
# Processing Record 27 of Set 1 | new norfolk
# Processing Record 28 of Set 1 | faanui
# Processing Record 29 of Set 1 | honiara
# Processing Record 30 of Set 1 | barrow
# Processing Record 31 of Set 1 | qaanaaq
# Processing Record 32 of Set 1 | coahuayana
# Processing Record 33 of Set 1 | jaru
# Processing Record 34 of Set 1 | virginia beach
# Processing Record 35 of Set 1 | namibe
# Processing Record 36 of Set 1 | nanortalik
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | carballo
# Processing Record 39 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 1 | booue
# Processing Record 41 of Set 1 | rudnichnyy
# Processing Record 42 of Set 1 | slonim
# Processing Record 43 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 1 | quatre cocos
# Processing Record 45 of Set 1 | micheweni
# Processing Record 46 of Set 1 | grand-santi
# Processing Record 47 of Set 1 | camacha
# Processing Record 48 of Set 1 | hambantota
# Processing Record 49 of Set 1 | thompson
# Processing Record 50 of Set 1 | butaritari
# Processing Record 1 of Set 2 | pevek
# Processing Record 2 of Set 2 | lebu
# Processing Record 3 of Set 2 | mar del plata
# Processing Record 4 of Set 2 | vila velha
# Processing Record 5 of Set 2 | port alfred
# Processing Record 6 of Set 2 | bluff
# Processing Record 7 of Set 2 | tiksi
# Processing Record 8 of Set 2 | albany
# Processing Record 9 of Set 2 | karimganj
# Processing Record 10 of Set 2 | puerto ayora
# Processing Record 11 of Set 2 | sisimiut
# Processing Record 12 of Set 2 | ossora
# Processing Record 13 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 2 | jamestown
# Processing Record 15 of Set 2 | san rafael del sur
# Processing Record 16 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 17 of Set 2 | husavik
# Processing Record 18 of Set 2 | hobart
# Processing Record 19 of Set 2 | kruisfontein
# Processing Record 20 of Set 2 | dikson
# Processing Record 21 of Set 2 | bundaberg
# Processing Record 22 of Set 2 | mataura
# Processing Record 23 of Set 2 | kenai
# Processing Record 24 of Set 2 | broome
# Processing Record 25 of Set 2 | constitucion
# Processing Record 26 of Set 2 | jirkov
# Processing Record 27 of Set 2 | longyearbyen
# Processing Record 28 of Set 2 | sorland
# Processing Record 29 of Set 2 | hervey bay
# Processing Record 30 of Set 2 | jingdezhen
# Processing Record 31 of Set 2 | ostrovnoy
# Processing Record 32 of Set 2 | coronado
# Processing Record 33 of Set 2 | singarayakonda
# Processing Record 34 of Set 2 | jinchengjiang
# City not found. Skipping...
# Processing Record 35 of Set 2 | victoria
# Processing Record 36 of Set 2 | damietta
# Processing Record 37 of Set 2 | lisala
# Processing Record 38 of Set 2 | cervo
# Processing Record 39 of Set 2 | padang
# Processing Record 40 of Set 2 | caborca
# Processing Record 41 of Set 2 | east london
# Processing Record 42 of Set 2 | jining
# Processing Record 43 of Set 2 | narsaq
# Processing Record 44 of Set 2 | peskovka
# Processing Record 45 of Set 2 | tasiilaq
# Processing Record 46 of Set 2 | portland
# Processing Record 47 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 2 | kampong cham
# Processing Record 49 of Set 2 | tura
# Processing Record 50 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 3 | douentza
# Processing Record 2 of Set 3 | madaoua
# Processing Record 3 of Set 3 | klaksvik
# Processing Record 4 of Set 3 | bilma
# Processing Record 5 of Set 3 | pokosnoye
# Processing Record 6 of Set 3 | ban nahin
# Processing Record 7 of Set 3 | nikolskoye
# Processing Record 8 of Set 3 | simbahan
# Processing Record 9 of Set 3 | juifang
# City not found. Skipping...
# Processing Record 10 of Set 3 | manaia
# Processing Record 11 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 3 | baraya
# Processing Record 13 of Set 3 | cabo san lucas
# Processing Record 14 of Set 3 | gat
# Processing Record 15 of Set 3 | airai
# Processing Record 16 of Set 3 | georgetown
# Processing Record 17 of Set 3 | coihaique
# Processing Record 18 of Set 3 | chokurdakh
# Processing Record 19 of Set 3 | aklavik
# Processing Record 20 of Set 3 | yarensk
# Processing Record 21 of Set 3 | hilo
# Processing Record 22 of Set 3 | avarua
# Processing Record 23 of Set 3 | vila franca do campo
# Processing Record 24 of Set 3 | castro
# Processing Record 25 of Set 3 | vao
# Processing Record 26 of Set 3 | ulladulla
# Processing Record 27 of Set 3 | port elizabeth
# Processing Record 28 of Set 3 | nome
# Processing Record 29 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 30 of Set 3 | necochea
# Processing Record 31 of Set 3 | vostok
# Processing Record 32 of Set 3 | eydhafushi
# Processing Record 33 of Set 3 | arraial do cabo
# Processing Record 34 of Set 3 | westport
# Processing Record 35 of Set 3 | santiago del estero
# Processing Record 36 of Set 3 | dunedin
# Processing Record 37 of Set 3 | avallon
# Processing Record 38 of Set 3 | upernavik
# Processing Record 39 of Set 3 | tautira
# Processing Record 40 of Set 3 | vuktyl
# Processing Record 41 of Set 3 | strezhevoy
# Processing Record 42 of Set 3 | yenangyaung
# Processing Record 43 of Set 3 | illapel
# Processing Record 44 of Set 3 | bengkulu
# Processing Record 45 of Set 3 | andros town
# Processing Record 46 of Set 3 | juliaca
# Processing Record 47 of Set 3 | fethiye
# Processing Record 48 of Set 3 | kavieng
# Processing Record 49 of Set 3 | kihei
# Processing Record 50 of Set 3 | bethel
# Processing Record 1 of Set 4 | sirjan
# Processing Record 2 of Set 4 | haian
# Processing Record 3 of Set 4 | mount gambier
# Processing Record 4 of Set 4 | bomet
# Processing Record 5 of Set 4 | rafaela
# Processing Record 6 of Set 4 | karratha
# Processing Record 7 of Set 4 | kloulklubed
# Processing Record 8 of Set 4 | saint george
# Processing Record 9 of Set 4 | prado
# Processing Record 10 of Set 4 | turukhansk
# Processing Record 11 of Set 4 | lazaro cardenas
# Processing Record 12 of Set 4 | mitsamiouli
# Processing Record 13 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 4 | kovdor
# Processing Record 15 of Set 4 | shkotovo-26
# City not found. Skipping...
# Processing Record 16 of Set 4 | dunmore east
# Processing Record 17 of Set 4 | cherskiy
# Processing Record 18 of Set 4 | henties bay
# Processing Record 19 of Set 4 | avera
# Processing Record 20 of Set 4 | pakhni
# Processing Record 21 of Set 4 | batagay-alyta
# Processing Record 22 of Set 4 | khartoum
# Processing Record 23 of Set 4 | teknaf
# Processing Record 24 of Set 4 | buqayq
# City not found. Skipping...
# Processing Record 25 of Set 4 | karwar
# Processing Record 26 of Set 4 | novoagansk
# Processing Record 27 of Set 4 | sitka
# Processing Record 28 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 29 of Set 4 | vikulovo
# Processing Record 30 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 4 | kodiak
# Processing Record 32 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 4 | palmer
# Processing Record 34 of Set 4 | leningradskiy
# Processing Record 35 of Set 4 | ponta do sol
# Processing Record 36 of Set 4 | tanggu
# Processing Record 37 of Set 4 | waipawa
# Processing Record 38 of Set 4 | celestun
# Processing Record 39 of Set 4 | kapoeta
# Processing Record 40 of Set 4 | flin flon
# Processing Record 41 of Set 4 | chifeng
# Processing Record 42 of Set 4 | banyo
# Processing Record 43 of Set 4 | matagami
# Processing Record 44 of Set 4 | naze
# Processing Record 45 of Set 4 | sovetskiy
# Processing Record 46 of Set 4 | frome
# Processing Record 47 of Set 4 | dicabisagan
# Processing Record 48 of Set 4 | minbu
# Processing Record 49 of Set 4 | iqaluit
# Processing Record 50 of Set 4 | lompoc
# Processing Record 1 of Set 5 | gua
# Processing Record 2 of Set 5 | purranque
# Processing Record 3 of Set 5 | guerrero negro
# Processing Record 4 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 5 | clyde river
# Processing Record 6 of Set 5 | fortuna
# Processing Record 7 of Set 5 | berlevag
# Processing Record 8 of Set 5 | goderich
# Processing Record 9 of Set 5 | sinkat
# City not found. Skipping...
# Processing Record 10 of Set 5 | carauari
# Processing Record 11 of Set 5 | ilo
# Processing Record 12 of Set 5 | lodwar
# Processing Record 13 of Set 5 | saskylakh
# Processing Record 14 of Set 5 | enumclaw
# Processing Record 15 of Set 5 | severo-kurilsk
# Processing Record 16 of Set 5 | chipiona
# Processing Record 17 of Set 5 | ciledug
# City not found. Skipping...
# Processing Record 18 of Set 5 | tungor
# Processing Record 19 of Set 5 | sibolga
# Processing Record 20 of Set 5 | vanimo
# Processing Record 21 of Set 5 | qujing
# Processing Record 22 of Set 5 | carnarvon
# Processing Record 23 of Set 5 | poronaysk
# Processing Record 24 of Set 5 | hillsborough
# Processing Record 25 of Set 5 | kiras vrisi
# City not found. Skipping...
# Processing Record 26 of Set 5 | ancud
# Processing Record 27 of Set 5 | khatanga
# Processing Record 28 of Set 5 | chuy
# Processing Record 29 of Set 5 | san felipe
# Processing Record 30 of Set 5 | namatanai
# Processing Record 31 of Set 5 | quelimane
# Processing Record 32 of Set 5 | san cristobal
# Processing Record 33 of Set 5 | beringovskiy
# Processing Record 34 of Set 5 | marystown
# Processing Record 35 of Set 5 | pochutla
# Processing Record 36 of Set 5 | haradok
# Processing Record 37 of Set 5 | chapais
# Processing Record 38 of Set 5 | peer
# Processing Record 39 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 40 of Set 5 | marawi
# Processing Record 41 of Set 5 | kupang
# Processing Record 42 of Set 5 | tomatlan
# Processing Record 43 of Set 5 | vestmannaeyjar
# Processing Record 44 of Set 5 | catuday
# Processing Record 45 of Set 5 | george town
# Processing Record 46 of Set 5 | torbay
# Processing Record 47 of Set 5 | fairbanks
# Processing Record 48 of Set 5 | north bend
# Processing Record 49 of Set 5 | roebourne
# Processing Record 50 of Set 5 | krutikha
# Processing Record 1 of Set 6 | matara
# Processing Record 2 of Set 6 | borujan
# City not found. Skipping...
# Processing Record 3 of Set 6 | magadan
# Processing Record 4 of Set 6 | warmbad
# Processing Record 5 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 6 | honningsvag
# Processing Record 7 of Set 6 | norman wells
# Processing Record 8 of Set 6 | huilong
# Processing Record 9 of Set 6 | vanino
# Processing Record 10 of Set 6 | hobyo
# Processing Record 11 of Set 6 | kribi
# Processing Record 12 of Set 6 | bandarbeyla
# Processing Record 13 of Set 6 | lodja
# Processing Record 14 of Set 6 | wadena
# Processing Record 15 of Set 6 | port said
# Processing Record 16 of Set 6 | rafai
# Processing Record 17 of Set 6 | santa barbara
# Processing Record 18 of Set 6 | san quintin
# Processing Record 19 of Set 6 | ust-tsilma
# Processing Record 20 of Set 6 | tilichiki
# Processing Record 21 of Set 6 | soure
# Processing Record 22 of Set 6 | samana
# Processing Record 23 of Set 6 | souillac
# Processing Record 24 of Set 6 | preston
# Processing Record 25 of Set 6 | saldanha
# Processing Record 26 of Set 6 | tshikapa
# Processing Record 27 of Set 6 | nadym
# Processing Record 28 of Set 6 | hangu
# Processing Record 29 of Set 6 | pacific grove
# Processing Record 30 of Set 6 | asfi
# Processing Record 31 of Set 6 | santarem
# Processing Record 32 of Set 6 | kieta
# Processing Record 33 of Set 6 | lufilufi
# Processing Record 34 of Set 6 | minsk
# Processing Record 35 of Set 6 | beitbridge
# Processing Record 36 of Set 6 | golubitskaya
# Processing Record 37 of Set 6 | nizwa
# Processing Record 38 of Set 6 | miri
# Processing Record 39 of Set 6 | kemi
# Processing Record 40 of Set 6 | merauke
# Processing Record 41 of Set 6 | college
# Processing Record 42 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 6 | lollar
# Processing Record 44 of Set 6 | pisco
# Processing Record 45 of Set 6 | afmadu
# City not found. Skipping...
# Processing Record 46 of Set 6 | shimoga
# Processing Record 47 of Set 6 | dhidhdhoo
# Processing Record 48 of Set 6 | havelock
# Processing Record 49 of Set 6 | keuruu
# Processing Record 50 of Set 6 | skelleftea
# Processing Record 1 of Set 7 | vestmanna
# Processing Record 2 of Set 7 | abu kamal
# Processing Record 3 of Set 7 | sobolevo
# Processing Record 4 of Set 7 | bukama
# Processing Record 5 of Set 7 | muros
# Processing Record 6 of Set 7 | zyryanka
# Processing Record 7 of Set 7 | lorengau
# Processing Record 8 of Set 7 | catio
# Processing Record 9 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 10 of Set 7 | andevoranto
# City not found. Skipping...
# Processing Record 11 of Set 7 | codrington
# Processing Record 12 of Set 7 | bukene
# Processing Record 13 of Set 7 | minas
# Processing Record 14 of Set 7 | samarai
# Processing Record 15 of Set 7 | rio gallegos
# Processing Record 16 of Set 7 | pandharpur
# Processing Record 17 of Set 7 | kawalu
# Processing Record 18 of Set 7 | bria
# Processing Record 19 of Set 7 | ukiah
# Processing Record 20 of Set 7 | los llanos de aridane
# Processing Record 21 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 22 of Set 7 | warrnambool
# Processing Record 23 of Set 7 | rawson
# Processing Record 24 of Set 7 | andilamena
# Processing Record 25 of Set 7 | duz
# City not found. Skipping...
# Processing Record 26 of Set 7 | faya
# Processing Record 27 of Set 7 | borba
# Processing Record 28 of Set 7 | hovd
# Processing Record 29 of Set 7 | lavrentiya
# Processing Record 30 of Set 7 | ilulissat
# Processing Record 31 of Set 7 | carutapera
# Processing Record 32 of Set 7 | korla
# Processing Record 33 of Set 7 | dingle
# Processing Record 34 of Set 7 | la ronge
# Processing Record 35 of Set 7 | bowen
# Processing Record 36 of Set 7 | alvorada
# Processing Record 37 of Set 7 | mogadishu
# Processing Record 38 of Set 7 | eskasem
# City not found. Skipping...
# Processing Record 39 of Set 7 | richards bay
# Processing Record 40 of Set 7 | chernyshevskiy
# Processing Record 41 of Set 7 | tuatapere
# Processing Record 42 of Set 7 | oron
# Processing Record 43 of Set 7 | tateyama
# Processing Record 44 of Set 7 | caravelas
# Processing Record 45 of Set 7 | tessalit
# Processing Record 46 of Set 7 | corrente
# Processing Record 47 of Set 7 | hearst
# Processing Record 48 of Set 7 | yilan
# Processing Record 49 of Set 7 | katsuura
# Processing Record 50 of Set 7 | general roca
# Processing Record 1 of Set 8 | hunza
# City not found. Skipping...
# Processing Record 2 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 3 of Set 8 | monteagudo
# Processing Record 4 of Set 8 | belaya gora
# Processing Record 5 of Set 8 | saint-augustin
# Processing Record 6 of Set 8 | touros
# Processing Record 7 of Set 8 | qasigiannguit
# Processing Record 8 of Set 8 | flinders
# Processing Record 9 of Set 8 | leh
# Processing Record 10 of Set 8 | shingu
# Processing Record 11 of Set 8 | mizdah
# Processing Record 12 of Set 8 | asau
# Processing Record 13 of Set 8 | okhotsk
# Processing Record 14 of Set 8 | gurskoye
# City not found. Skipping...
# Processing Record 15 of Set 8 | nikaia
# Processing Record 16 of Set 8 | cururupu
# Processing Record 17 of Set 8 | provideniya
# Processing Record 18 of Set 8 | porto walter
# Processing Record 19 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 8 | okha
# Processing Record 21 of Set 8 | kudat
# Processing Record 22 of Set 8 | ouadda
# Processing Record 23 of Set 8 | solton
# Processing Record 24 of Set 8 | labrea
# Processing Record 25 of Set 8 | damaturu
# Processing Record 26 of Set 8 | colesberg
# Processing Record 27 of Set 8 | tecoanapa
# Processing Record 28 of Set 8 | arkhangelsk
# Processing Record 29 of Set 8 | kyaiklat
# Processing Record 30 of Set 8 | thinadhoo
# Processing Record 31 of Set 8 | jabiru
# City not found. Skipping...
# Processing Record 32 of Set 8 | saint-honore
# Processing Record 33 of Set 8 | mubi
# Processing Record 34 of Set 8 | port hardy
# Processing Record 35 of Set 8 | olinda
# Processing Record 36 of Set 8 | walvis bay
# Processing Record 37 of Set 8 | margate
# Processing Record 38 of Set 8 | ulaanbaatar
# Processing Record 39 of Set 8 | nouadhibou
# Processing Record 40 of Set 8 | trzcianka
# Processing Record 41 of Set 8 | leshukonskoye
# Processing Record 42 of Set 8 | yulara
# Processing Record 43 of Set 8 | anadyr
# Processing Record 44 of Set 8 | mayo
# Processing Record 45 of Set 8 | salalah
# Processing Record 46 of Set 8 | ribeira brava
# Processing Record 47 of Set 8 | ambanja
# Processing Record 48 of Set 8 | eldikan
# City not found. Skipping...
# Processing Record 49 of Set 8 | kaiyuan
# Processing Record 50 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 9 | galle
# Processing Record 2 of Set 9 | maymanak
# City not found. Skipping...
# Processing Record 3 of Set 9 | bareli
# Processing Record 4 of Set 9 | sulangan
# Processing Record 5 of Set 9 | huambo
# Processing Record 6 of Set 9 | alice springs
# Processing Record 7 of Set 9 | bathsheba
# Processing Record 8 of Set 9 | villa florida
# Processing Record 9 of Set 9 | tatarsk
# Processing Record 10 of Set 9 | kazachinskoye
# Processing Record 11 of Set 9 | panaba
# Processing Record 12 of Set 9 | pumiao
# Processing Record 13 of Set 9 | fomboni
# Processing Record 14 of Set 9 | livingston
# Processing Record 15 of Set 9 | sola
# Processing Record 16 of Set 9 | akdepe
# Processing Record 17 of Set 9 | saint-louis
# Processing Record 18 of Set 9 | tabou
# Processing Record 19 of Set 9 | gravelbourg
# Processing Record 20 of Set 9 | saint-philippe
# Processing Record 21 of Set 9 | homer
# Processing Record 22 of Set 9 | bairiki
# Processing Record 23 of Set 9 | zlobin
# Processing Record 24 of Set 9 | ha giang
# Processing Record 25 of Set 9 | lander
# Processing Record 26 of Set 9 | zarubino
# Processing Record 27 of Set 9 | wanning
# Processing Record 28 of Set 9 | catemaco
# Processing Record 29 of Set 9 | moranbah
# Processing Record 30 of Set 9 | paamiut
# Processing Record 31 of Set 9 | doha
# Processing Record 32 of Set 9 | natal
# Processing Record 33 of Set 9 | ouesso
# Processing Record 34 of Set 9 | aksarka
# Processing Record 35 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 9 | manta
# Processing Record 37 of Set 9 | daxian
# City not found. Skipping...
# Processing Record 38 of Set 9 | mimongo
# Processing Record 39 of Set 9 | cabedelo
# Processing Record 40 of Set 9 | senhor do bonfim
# Processing Record 41 of Set 9 | savinka
# Processing Record 42 of Set 9 | banda aceh
# Processing Record 43 of Set 9 | srivardhan
# Processing Record 44 of Set 9 | reidsville
# Processing Record 45 of Set 9 | saint-joseph
# Processing Record 46 of Set 9 | aguimes
# Processing Record 47 of Set 9 | rovinj
# Processing Record 48 of Set 9 | lasa
# Processing Record 49 of Set 9 | adrar
# Processing Record 50 of Set 9 | muncar
# Processing Record 1 of Set 10 | kochki
# Processing Record 2 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 10 | toktogul
# Processing Record 4 of Set 10 | kaitangata
# Processing Record 5 of Set 10 | bhadrachalam
# Processing Record 6 of Set 10 | nanakuli
# Processing Record 7 of Set 10 | port lincoln
# Processing Record 8 of Set 10 | qurayyat
# Processing Record 9 of Set 10 | verkhnyaya inta
# Processing Record 10 of Set 10 | ulaangom
# Processing Record 11 of Set 10 | qarayeri
# Processing Record 12 of Set 10 | ashqelon
# Processing Record 13 of Set 10 | lar gerd
# City not found. Skipping...
# Processing Record 14 of Set 10 | vila
# Processing Record 15 of Set 10 | kahului
# Processing Record 16 of Set 10 | calama
# Processing Record 17 of Set 10 | cidreira
# Processing Record 18 of Set 10 | beyneu
# Processing Record 19 of Set 10 | hami
# Processing Record 20 of Set 10 | linjiang
# Processing Record 21 of Set 10 | haines junction
# Processing Record 22 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 23 of Set 10 | half moon bay
# Processing Record 24 of Set 10 | kita
# Processing Record 25 of Set 10 | georgiyevka
# Processing Record 26 of Set 10 | zhigansk
# Processing Record 27 of Set 10 | bubaque
# Processing Record 28 of Set 10 | petatlan
# Processing Record 29 of Set 10 | anloga
# Processing Record 30 of Set 10 | belmonte
# Processing Record 31 of Set 10 | biak
# Processing Record 32 of Set 10 | gweta
# Processing Record 33 of Set 10 | broken hill
# Processing Record 34 of Set 10 | hualmay
# Processing Record 35 of Set 10 | luderitz
# Processing Record 36 of Set 10 | rincon
# Processing Record 37 of Set 10 | caapora
# Processing Record 38 of Set 10 | biggar
# Processing Record 39 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 40 of Set 10 | aransas pass
# Processing Record 41 of Set 10 | clonakilty
# Processing Record 42 of Set 10 | huarmey
# Processing Record 43 of Set 10 | socorro
# Processing Record 44 of Set 10 | opelousas
# Processing Record 45 of Set 10 | sao bernardo
# Processing Record 46 of Set 10 | kudahuvadhoo
# Processing Record 47 of Set 10 | eureka
# Processing Record 48 of Set 10 | sao felix do xingu
# Processing Record 49 of Set 10 | sibut
# Processing Record 50 of Set 10 | hamilton
# Processing Record 1 of Set 11 | puqi
# Processing Record 2 of Set 11 | dire dawa
# Processing Record 3 of Set 11 | duekoue
# Processing Record 4 of Set 11 | palakkad
# Processing Record 5 of Set 11 | tutoia
# Processing Record 6 of Set 11 | yoichi
# Processing Record 7 of Set 11 | powell
# Processing Record 8 of Set 11 | ayr
# Processing Record 9 of Set 11 | evanston
# Processing Record 10 of Set 11 | havre-saint-pierre
# Processing Record 11 of Set 11 | sibu
# Processing Record 12 of Set 11 | manuk mangkaw
# Processing Record 13 of Set 11 | herzberg
# Processing Record 14 of Set 11 | marabba
# Processing Record 15 of Set 11 | sale
# Processing Record 16 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 11 | ocampo
# Processing Record 18 of Set 11 | makarov
# Processing Record 19 of Set 11 | suzaka
# Processing Record 20 of Set 11 | rudbar
# Processing Record 21 of Set 11 | qingdao
# Processing Record 22 of Set 11 | estelle
# Processing Record 23 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 11 | abnub
# Processing Record 25 of Set 11 | kirakira
# Processing Record 26 of Set 11 | rocha
# Processing Record 27 of Set 11 | yiyang
# Processing Record 28 of Set 11 | waingapu
# Processing Record 29 of Set 11 | benguela
# Processing Record 30 of Set 11 | bambous virieux
# Processing Record 31 of Set 11 | belmont
# Processing Record 32 of Set 11 | praia da vitoria
# Processing Record 33 of Set 11 | keizer
# Processing Record 34 of Set 11 | soc trang
# Processing Record 35 of Set 11 | yar-sale
# Processing Record 36 of Set 11 | neftegorsk
# Processing Record 37 of Set 11 | troitskoye
# Processing Record 38 of Set 11 | ures
# Processing Record 39 of Set 11 | umm kaddadah
# Processing Record 40 of Set 11 | eyl
# Processing Record 41 of Set 11 | austin
# Processing Record 42 of Set 11 | aswan
# Processing Record 43 of Set 11 | karakose
# City not found. Skipping...
# Processing Record 44 of Set 11 | kropotkin
# Processing Record 45 of Set 11 | mount isa
# Processing Record 46 of Set 11 | inhambane
# Processing Record 47 of Set 11 | rorvik
# Processing Record 48 of Set 11 | brae
# Processing Record 49 of Set 11 | imbituba
# Processing Record 50 of Set 11 | kurya
# Processing Record 1 of Set 12 | alofi
# Processing Record 2 of Set 12 | itarsi
# Processing Record 3 of Set 12 | hattiesburg
# Processing Record 4 of Set 12 | abay
# Processing Record 5 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 6 of Set 12 | lac-au-saumon
# Processing Record 7 of Set 12 | amberley
# Processing Record 8 of Set 12 | pandaria
# Processing Record 9 of Set 12 | bhindar
# Processing Record 10 of Set 12 | otradnoye
# Processing Record 11 of Set 12 | puerto colombia
# Processing Record 12 of Set 12 | ixtapa
# Processing Record 13 of Set 12 | luau
# Processing Record 14 of Set 12 | byron bay
# Processing Record 15 of Set 12 | malko tarnovo
# Processing Record 16 of Set 12 | sao joao da barra
# Processing Record 17 of Set 12 | benghazi
# Processing Record 18 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 19 of Set 12 | komsomolskiy
# Processing Record 20 of Set 12 | zarautz
# Processing Record 21 of Set 12 | cleburne
# Processing Record 22 of Set 12 | yatou
# Processing Record 23 of Set 12 | skhisma
# Processing Record 24 of Set 12 | kawardha
# Processing Record 25 of Set 12 | havoysund
# Processing Record 26 of Set 12 | mookane
# Processing Record 27 of Set 12 | prince george
# Processing Record 28 of Set 12 | kushima
# Processing Record 29 of Set 12 | kamenka
# Processing Record 30 of Set 12 | chumikan
# Processing Record 31 of Set 12 | udachnyy
# Processing Record 32 of Set 12 | sioux lookout
# Processing Record 33 of Set 12 | do gonbadan
# Processing Record 34 of Set 12 | dongfeng
# Processing Record 35 of Set 12 | ahipara
# Processing Record 36 of Set 12 | port macquarie
# Processing Record 37 of Set 12 | the valley
# Processing Record 38 of Set 12 | champerico
# Processing Record 39 of Set 12 | verkhnetulomskiy
# Processing Record 40 of Set 12 | xining
# Processing Record 41 of Set 12 | great yarmouth
# Processing Record 42 of Set 12 | yate
# Processing Record 43 of Set 12 | port moresby
# Processing Record 44 of Set 12 | talnakh
# Processing Record 45 of Set 12 | ust-nera
# Processing Record 46 of Set 12 | kushiro
# Processing Record 47 of Set 12 | huanren
# Processing Record 48 of Set 12 | launceston
# Processing Record 49 of Set 12 | muravlenko
# Processing Record 50 of Set 12 | fukuma
# Processing Record 1 of Set 13 | meulaboh
# Processing Record 2 of Set 13 | chicama
# Processing Record 3 of Set 13 | gilgit
# Processing Record 4 of Set 13 | puerto ayacucho
# Processing Record 5 of Set 13 | biloela
# Processing Record 6 of Set 13 | dickinson
# Processing Record 7 of Set 13 | cusuna
# Processing Record 8 of Set 13 | harrisburg
# Processing Record 9 of Set 13 | praia
# Processing Record 10 of Set 13 | grindavik
# Processing Record 11 of Set 13 | sinnamary
# Processing Record 12 of Set 13 | tibu
# Processing Record 13 of Set 13 | tangwani
# Processing Record 14 of Set 13 | sabha
# Processing Record 15 of Set 13 | te anau
# Processing Record 16 of Set 13 | luzhou
# Processing Record 17 of Set 13 | ukmerge
# Processing Record 18 of Set 13 | svetlyy
# Processing Record 19 of Set 13 | nabire
# Processing Record 20 of Set 13 | nuuk
# Processing Record 21 of Set 13 | surt
# Processing Record 22 of Set 13 | mezen
# Processing Record 23 of Set 13 | allanridge
# Processing Record 24 of Set 13 | kurilsk
# Processing Record 25 of Set 13 | serebryansk
# Processing Record 26 of Set 13 | marienburg
# Processing Record 27 of Set 13 | yasnyy
# Processing Record 28 of Set 13 | copiapo
# Processing Record 29 of Set 13 | sheridan
# Processing Record 30 of Set 13 | bianzhuang
# Processing Record 31 of Set 13 | bontang
# Processing Record 32 of Set 13 | hunterville
# Processing Record 33 of Set 13 | besikduzu
# Processing Record 34 of Set 13 | san patricio
# Processing Record 35 of Set 13 | orgun
# City not found. Skipping...
# Processing Record 36 of Set 13 | esperance
# Processing Record 37 of Set 13 | lake havasu city
# Processing Record 38 of Set 13 | deputatskiy
# Processing Record 39 of Set 13 | los cordobas
# Processing Record 40 of Set 13 | kalininsk
# Processing Record 41 of Set 13 | taoudenni
# Processing Record 42 of Set 13 | misratah
# Processing Record 43 of Set 13 | fukue
# Processing Record 44 of Set 13 | qaqortoq
# Processing Record 45 of Set 13 | saint anthony
# Processing Record 46 of Set 13 | saint-francois
# Processing Record 47 of Set 13 | makokou
# Processing Record 48 of Set 13 | luanda
# Processing Record 49 of Set 13 | siniscola
# Processing Record 50 of Set 13 | tokat
# Processing Record 1 of Set 14 | kutum
# Processing Record 2 of Set 14 | elat
# Processing Record 3 of Set 14 | antofagasta
# Processing Record 4 of Set 14 | plettenberg bay
# Processing Record 5 of Set 14 | tenabo
# Processing Record 6 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 7 of Set 14 | isangel
# Processing Record 8 of Set 14 | mehamn
# Processing Record 9 of Set 14 | marsa matruh
# Processing Record 10 of Set 14 | ormond beach
# Processing Record 11 of Set 14 | qandala
# Processing Record 12 of Set 14 | bafra
# Processing Record 13 of Set 14 | artyom
# Processing Record 14 of Set 14 | atar
# Processing Record 15 of Set 14 | shenjiamen
# Processing Record 16 of Set 14 | ayan
# Processing Record 17 of Set 14 | skopelos
# Processing Record 18 of Set 14 | belyy yar
# Processing Record 19 of Set 14 | manono
# Processing Record 20 of Set 14 | fredonia
# Processing Record 21 of Set 14 | navalcarnero
# Processing Record 22 of Set 14 | muhos
# Processing Record 23 of Set 14 | roald
# Processing Record 24 of Set 14 | poum
# Processing Record 25 of Set 14 | maryville
# Processing Record 26 of Set 14 | geraldton
# Processing Record 27 of Set 14 | majene
# Processing Record 28 of Set 14 | knysna
# Processing Record 29 of Set 14 | caruray
# Processing Record 30 of Set 14 | saravan
# Processing Record 31 of Set 14 | solsona
# Processing Record 32 of Set 14 | soma
# Processing Record 33 of Set 14 | nenjiang
# Processing Record 34 of Set 14 | linden
# Processing Record 35 of Set 14 | zaraza
# Processing Record 36 of Set 14 | buala
# Processing Record 37 of Set 14 | onverwacht
# Processing Record 38 of Set 14 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 14 | vysokogornyy
# Processing Record 40 of Set 14 | ouargaye
# Processing Record 41 of Set 14 | osakarovka
# Processing Record 42 of Set 14 | yarada
# Processing Record 43 of Set 14 | solntsevo
# Processing Record 44 of Set 14 | baikunthpur
# Processing Record 45 of Set 14 | dongsheng
# Processing Record 46 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 47 of Set 14 | el alto
# Processing Record 48 of Set 14 | longlac
# City not found. Skipping...
# Processing Record 49 of Set 14 | saint-pierre
# Processing Record 50 of Set 14 | yomitan
# City not found. Skipping...
# Processing Record 1 of Set 15 | tezu
# Processing Record 2 of Set 15 | avondale
# Processing Record 3 of Set 15 | urucui
# Processing Record 4 of Set 15 | sinop
# Processing Record 5 of Set 15 | paita
# Processing Record 6 of Set 15 | port blair
# Processing Record 7 of Set 15 | okato
# Processing Record 8 of Set 15 | kamaishi
# Processing Record 9 of Set 15 | hammerfest
# Processing Record 10 of Set 15 | marzuq
# Processing Record 11 of Set 15 | tambopata
# Processing Record 12 of Set 15 | casper
# Processing Record 13 of Set 15 | san antonio
# Processing Record 14 of Set 15 | ketchikan
# Processing Record 15 of Set 15 | toora-khem
# Processing Record 16 of Set 15 | zhangye
# Processing Record 17 of Set 15 | bogorodskoye
# Processing Record 18 of Set 15 | palana
# Processing Record 19 of Set 15 | makinsk
# Processing Record 20 of Set 15 | payo
# Processing Record 21 of Set 15 | vanavara
# Processing Record 22 of Set 15 | gushikawa
# Processing Record 23 of Set 15 | guiglo
# Processing Record 24 of Set 15 | komatsushima
# Processing Record 25 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 26 of Set 15 | luganville
# Processing Record 27 of Set 15 | suez
# Processing Record 28 of Set 15 | darhan
# Processing Record 29 of Set 15 | arlit
# Processing Record 30 of Set 15 | skibbereen
# Processing Record 31 of Set 15 | burkhala
# City not found. Skipping...
# Processing Record 32 of Set 15 | atambua
# Processing Record 33 of Set 15 | beloha
# Processing Record 34 of Set 15 | vardo
# Processing Record 35 of Set 15 | abbeville
# Processing Record 36 of Set 15 | jacksonville
# Processing Record 37 of Set 15 | milingimbi
# City not found. Skipping...
# Processing Record 38 of Set 15 | port hedland
# Processing Record 39 of Set 15 | auki
# Processing Record 40 of Set 15 | khalkhal
# Processing Record 41 of Set 15 | uige
# Processing Record 42 of Set 15 | saint joseph
# Processing Record 43 of Set 15 | honavar
# Processing Record 44 of Set 15 | neiafu
# Processing Record 45 of Set 15 | gisborne
# Processing Record 46 of Set 15 | ugra
# Processing Record 47 of Set 15 | olafsvik
# Processing Record 48 of Set 15 | namie
# Processing Record 49 of Set 15 | muzhi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20072\3305526042.py in <module>
#       1 # Print the length of the city_data list to verify how many cities you have
# ----> 2 len(city_data)
#
# NameError: name 'city_data' is not defined

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20072\454107717.py in <module>
#       1 # Use the city_data list to create a new pandas DataFrame.
# ----> 2 city_data_df = pd.DataFrame(city_data)
#
# NameError: name 'pd' is not defined

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Busselton -33.6500  115.3333     59.38        46          44
# 1      Hermanus -34.4187   19.2345     61.81        93          99
# 2     Cape Town -33.9258   18.4232     63.01        84          40
# 3     Hithadhoo  -0.6000   73.0833     82.20        76          98
# 4    Bredasdorp -34.5322   20.0403     56.97        96         100
# 5   Tuktoyaktuk  69.4541 -133.0374     32.00        74         100
# 6  Vangaindrano -23.3500   47.6000     66.06        90          45
# 7     Kavaratti  10.5669   72.6420     81.28        74         100
# 8       Rikitea -23.1203 -134.9692     69.94        80          45
# 9        Hasaki  35.7333  140.8333     71.22        62         100
#
#    Wind Speed Country                 Date Current Description
# 0       11.18      AU  2022-10-12 02:46:34    scattered clouds
# 1        5.46      ZA  2022-10-12 02:46:34     overcast clouds
# 2       14.97      ZA  2022-10-12 02:45:03    scattered clouds
# 3       18.12      MV  2022-10-12 02:43:10     overcast clouds
# 4        0.92      ZA  2022-10-12 02:38:40     overcast clouds
# 5       14.97      CA  2022-10-12 02:46:38     overcast clouds
# 6        4.38      MG  2022-10-12 02:46:38    scattered clouds
# 7        6.20      IN  2022-10-12 02:46:39     overcast clouds
# 8       17.92      PF  2022-10-12 02:46:40          light rain
# 9       18.14      JP  2022-10-12 02:46:41     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order=["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df=city_data_df[new_column_order]


# Display sample data
city_data_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0     Busselton      AU  2022-10-12 02:46:34 -33.6500  115.3333     59.38
# 1      Hermanus      ZA  2022-10-12 02:46:34 -34.4187   19.2345     61.81
# 2     Cape Town      ZA  2022-10-12 02:45:03 -33.9258   18.4232     63.01
# 3     Hithadhoo      MV  2022-10-12 02:43:10  -0.6000   73.0833     82.20
# 4    Bredasdorp      ZA  2022-10-12 02:38:40 -34.5322   20.0403     56.97
# 5   Tuktoyaktuk      CA  2022-10-12 02:46:38  69.4541 -133.0374     32.00
# 6  Vangaindrano      MG  2022-10-12 02:46:38 -23.3500   47.6000     66.06
# 7     Kavaratti      IN  2022-10-12 02:46:39  10.5669   72.6420     81.28
# 8       Rikitea      PF  2022-10-12 02:46:40 -23.1203 -134.9692     69.94
# 9        Hasaki      JP  2022-10-12 02:46:41  35.7333  140.8333     71.22
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        46          44       11.18    scattered clouds
# 1        93          99        5.46     overcast clouds
# 2        84          40       14.97    scattered clouds
# 3        76          98       18.12     overcast clouds
# 4        96         100        0.92     overcast clouds
# 5        74         100       14.97     overcast clouds
# 6        90          45        4.38    scattered clouds
# 7        74         100        6.20     overcast clouds
# 8        80          45       17.92          light rain
# 9        62         100       18.14     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
datatypeseries=city_data_df.dtypes
datatypeseries
# Out:
# City                    object
# Country                 object
# Date                    object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
